# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
from ultralytics import YOLO
from pathlib import Path

# %%
# load YOLOv8 small (pretrained on COCO)
model = YOLO('yolov8s.pt')
# Out:
# ...
# 100%|██████████████████████████████████████| 21.5M/21.5M [00:03<00:00, 7.31MB/s]

# %%
soccer_path = Path('../pressure')
soccer_images = list(soccer_path.glob('*.png'))
imgs = [path.as_posix() for path in soccer_images]

# %%
# run on a single image or folder
results = model(imgs)  
annotated = results[0].plot()
# Out:
# 0: 640x640 11 persons, 1 sports ball, 1 tennis racket, 2.6ms
# 1: 640x640 20 persons, 2 sports balls, 2.6ms
# 2: 640x640 6 persons, 1 sports ball, 1 tennis racket, 2.6ms
# Speed: 3.7ms preprocess, 2.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)

# %%
plt.imshow(results[0].orig_img)

# %%
plt.imshow(results[0].plot())

# %%
plt.imshow(results[1].plot())

# %%
plt.imshow(results[2].plot())
